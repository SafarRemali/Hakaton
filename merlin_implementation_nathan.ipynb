# %%
#!pip install openpyxl

# %%
import matplotlib.pyplot as plt
import numpy as np
import perceval as pcvl
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from tqdm import tqdm

from merlin import LexGrouping, QuantumLayer, MeasurementStrategy, ComputationSpace
from merlin.builder import CircuitBuilder
import perceval as pcvl

import pandas as pd
import os

# %%
DATA_PATH = "./train.xlsx"

# %% [markdown]
# # Loading data

# %%
# Load training data (day-first dates)
df = pd.read_excel(DATA_PATH)
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df = df.sort_values('Date').reset_index(drop=True)

# Keep Date as first column
df = df[['Date'] + [c for c in df.columns if c != 'Date']]
feature_cols = [c for c in df.columns if c != 'Date']

print(f"Rows: {len(df)}")
print(f"Date range: {df['Date'].min().date()} → {df['Date'].max().date()}")
print(f"Number of surface points: {len(feature_cols)}")

df.head()
# Out:
# Rows: 494
# Date range: 2050-01-01 → 2051-12-23
# Number of surface points: 224
#         Date  Tenor : 1; Maturity : 0.0833333333333333  \
# 0 2050-01-01                                  0.028565
# 1 2050-01-02                                  0.029334
# 2 2050-01-03                                  0.028696
# 3 2050-01-05                                  0.030854
# 4 2050-01-06                                  0.030406
#
#    Tenor : 2; Maturity : 0.0833333333333333  \
# 0                                  0.038700
# 1                                  0.039499
# 2                                  0.038816
# 3                                  0.041536
# 4                                  0.041174
#
#    Tenor : 3; Maturity : 0.0833333333333333  \
# 0                                  0.040127
# 1                                  0.040982
# 2                                  0.040328
# 3                                  0.043035
# 4                                  0.042681
#
#    Tenor : 4; Maturity : 0.0833333333333333  \
# 0                                  0.040762
# 1                                  0.041638
# 2                                  0.041042
# 3                                  0.043605
# 4                                  0.043266
#
#    Tenor : 5; Maturity : 0.0833333333333333  \
# 0                                  0.040466
# 1                                  0.041336
# 2                                  0.040804
# 3                                  0.043241
# 4                                  0.042937
#
#    Tenor : 6; Maturity : 0.0833333333333333  \
# 0                                  0.038953
# 1                                  0.039815
# 2                                  0.039329
# 3                                  0.041556
# 4                                  0.041253
#
#    Tenor : 7; Maturity : 0.0833333333333333  \
# 0                                  0.037553
# 1                                  0.038397
# 2                                  0.037968
# 3                                  0.039977
# 4                                  0.039685
#
#    Tenor : 8; Maturity : 0.0833333333333333  \
# 0                                  0.036768
# 1                                  0.037631
# 2                                  0.037216
# 3                                  0.039167
# 4                                  0.038867
#
#    Tenor : 9; Maturity : 0.0833333333333333  ...  Tenor : 5; Maturity : 30  \
# 0                                  0.036646  ...                  0.331053
# 1                                  0.037504  ...                  0.336319
# 2                                  0.037107  ...                  0.333634
# 3                                  0.038968  ...                  0.336884
# 4                                  0.038667  ...                  0.333249
#
#    Tenor : 6; Maturity : 30  Tenor : 7; Maturity : 30  \
# 0                  0.329056                  0.330997
# 1                  0.334434                  0.336568
# 2                  0.331707                  0.333800
# 3                  0.335106                  0.337548
# 4                  0.331426                  0.333830
#
#    Tenor : 8; Maturity : 30  Tenor : 9; Maturity : 30  \
# 0                  0.324676                  0.325758
# 1                  0.330244                  0.331462
# 2                  0.327487                  0.328710
# 3                  0.331279                  0.332811
# 4                  0.327580                  0.329123
#
#    Tenor : 10; Maturity : 30  Tenor : 15; Maturity : 30  \
# 0                   0.322393                   0.345859
# 1                   0.328144                   0.351816
# 2                   0.325436                   0.348915
# 3                   0.329771                   0.353246
# 4                   0.326146                   0.349390
#
#    Tenor : 20; Maturity : 30  Tenor : 25; Maturity : 30  \
# 0                   0.359162                   0.346670
# 1                   0.365197                   0.350993
# 2                   0.362236                   0.348652
# 3                   0.366100                   0.351404
# 4                   0.362048                   0.348331
#
#    Tenor : 30; Maturity : 30
# 0                   0.337670
# 1                   0.340822
# 2                   0.339027
# 3                   0.340465
# 4                   0.338022
#
# [5 rows x 225 columns]

# %%
class FinanceDataset(torch.utils.data.Dataset):
    """PyTorch Dataset for swaption volatility data."""
    
    def __init__(self, X, history):
        self.X = torch.FloatTensor(X.values if isinstance(X, pd.DataFrame) else X)
        self.history = history
    
    def __len__(self):
        return len(self.X) - self.history - 3
    
    def __getitem__(self, idx):
        return self.X[idx:idx+self.history], self.X[idx+self.history+1:idx+self.history+4]

# %%
# Build a simple PyTorch Dataset using the next-day target
history=6

X = df[feature_cols].copy()
y = df[feature_cols].shift(-1)

# drop last row where target is NaN
mask = ~y.isnull().any(axis=1)
X = X[mask].reset_index(drop=True)
y = y[mask].reset_index(drop=True)

dataset = FinanceDataset(X, history)
print(f"Dataset size: {len(dataset)} samples")
print(f"Feature dim: {X.shape[1]}, Target dim: {y.shape[1]}")

input_dim = X.shape[1]
target_dim = y.shape[1] * 3
dataset[0]
# Out:
# Dataset size: 484 samples
# Feature dim: 224, Target dim: 224
# (tensor([[0.0286, 0.0387, 0.0401,  ..., 0.3592, 0.3467, 0.3377],
#          [0.0293, 0.0395, 0.0410,  ..., 0.3652, 0.3510, 0.3408],
#          [0.0287, 0.0388, 0.0403,  ..., 0.3622, 0.3487, 0.3390],
#          [0.0309, 0.0415, 0.0430,  ..., 0.3661, 0.3514, 0.3405],
#          [0.0304, 0.0412, 0.0427,  ..., 0.3620, 0.3483, 0.3380],
#          [0.0301, 0.0402, 0.0418,  ..., 0.3743, 0.3572, 0.3453]]),
#  tensor([[0.0297, 0.0395, 0.0409, 0.0416, 0.0413, 0.0399, 0.0385, 0.0378, 0.0377,
#           0.0367, 0.0351, 0.0338, 0.0336, 0.0340, 0.0595, 0.0709, 0.0721, 0.0711,
#           0.0713, 0.0677, 0.0677, 0.0663, 0.0652, 0.0643, 0.0605, 0.0579, 0.0575,
#           0.0588, 0.0958, 0.1054, 0.1026, 0.1017, 0.1005, 0.0987, 0.0943, 0.0924,
#           0.0921, 0.0886, 0.0839, 0.0813, 0.0832, 0.0835, 0.1277, 0.1292, 0.1268,
#           0.1255, 0.1225, 0.1166, 0.1162, 0.1144, 0.1124, 0.1084, 0.1029, 0.1007,
#           0.0994, 0.1019, 0.1546, 0.1508, 0.1470, 0.1403, 0.1399, 0.1326, 0.1310,
#           0.1280, 0.1256, 0.1262, 0.1177, 0.1167, 0.1161, 0.1158, 0.1865, 0.1776,
#           0.1716, 0.1684, 0.1663, 0.1620, 0.1569, 0.1537, 0.1514, 0.1470, 0.1427,
#           0.1361, 0.1363, 0.1390, 0.2045, 0.1986, 0.1953, 0.1896, 0.1857, 0.1789,
#           0.1790, 0.1723, 0.1704, 0.1706, 0.1584, 0.1555, 0.1557, 0.1614, 0.2327,
#           0.2202, 0.2199, 0.2185, 0.2083, 0.2046, 0.2051, 0.2001, 0.2007, 0.1948,
#           0.2925, 0.3076, 0.3019, 0.3022, 0.3033, 0.3032, 0.3009, 0.2992, 0.2947,
#           0.2939, 0.2958, 0.2992, 0.3052, 0.3115, 0.3271, 0.3352, 0.3287, 0.3255,
#           0.3242, 0.3226, 0.3240, 0.3181, 0.3232, 0.3183, 0.3194, 0.3194, 0.3334,
#           0.3459, 0.3589, 0.3534, 0.3409, 0.3372, 0.3385, 0.3446, 0.3433, 0.3416,
#           0.3440, 0.3377, 0.3392, 0.3361, 0.3598, 0.3734, 0.3563, 0.3447]]))

# %%
from torch.utils.data import random_split, DataLoader

trainset, testset = random_split(dataset, [0.8, 0.2])

trainloader = DataLoader(trainset, batch_size=10, shuffle=True)
testloader = DataLoader(testset, batch_size=len(testset), shuffle=False)

# %%
# Parsing helpers
def parse_surface_metadata(df):
    tenors, maturities = [], []
    mapping = {}
    for col in df.columns:
        if col == 'Date':
            continue
        parts = col.split(';')
        tenor = float(parts[0].split(':')[1].strip())
        maturity = float(parts[1].split(':')[1].strip())
        tenors.append(tenor)
        maturities.append(maturity)
        mapping[col] = (tenor, maturity)
    return sorted(set(tenors)), sorted(set(maturities)), mapping

def surface_for_date(df, idx, unique_tenors, unique_maturities, mapping):
    row = df.iloc[idx]
    surface = np.full((len(unique_tenors), len(unique_maturities)), np.nan)
    for col, (t, m) in mapping.items():
        t_idx = unique_tenors.index(t)
        m_idx = unique_maturities.index(m)
        surface[t_idx, m_idx] = row[col]
    return surface

unique_tenors, unique_maturities, tm_map = parse_surface_metadata(df)
print(f"Tenors: {len(unique_tenors)} | Maturities: {len(unique_maturities)}")
# Out:
# Tenors: 14 | Maturities: 16

# %% [markdown]
# # Testing

# %%
def test(model, loader, device="cpu", tolerance=0.10, silent=True):
    model.eval()
    model.to(device)
    
    with torch.no_grad():
        inputs, targets_unflat = next(iter(loader))
        targets = torch.flatten(targets_unflat, start_dim=1)
        outputs = model(inputs)
        print("out shape", outputs.shape)

        sum_residual = torch.nn.functional.mse_loss(outputs, targets, reduction='sum').item()
        
        expectancy = torch.mean(targets)
        sum_square = torch.nn.functional.mse_loss(expectancy, targets, reduction='sum').item()  # Basically variance
        
        r_squared = 1 - sum_residual/sum_square
        
        mse = torch.nn.functional.mse_loss(outputs, targets, reduction='mean').item()
        root_mse = mse**.5
        mae = torch.nn.functional.mse_loss(outputs, targets, reduction='mean').item()
        
    if not silent:
        print(f"Test Results:")
        print("\t", f"MSE: {mse:.4f}")
        print("\t", f"Root MSE: {root_mse:.4f}")
        print("\t", f"MAE: {mae:.4f}")
        print("\t", f"R^2 (coefficient of determination): {r_squared:.4f}")
    
    return mse, root_mse, mae, r_squared

# %%
def example(model, loader):
    model.eval()
    
    with torch.no_grad():
        inputs, targets = next(iter(loader))
        outputs = model(inputs)
        
        relative_error = torch.abs(outputs - targets) / (torch.abs(targets) + 1e-7)
            
        print(f'Target={targets}, Output={outputs}, Rel_error={relative_error}')

# %% [markdown]
# # Training pipeline

# %%
def train(model, loss_fn, optim, n_epochs=10, device='cpu'):
    model.train()
    model.to(device)
    l = []

    pbar = tqdm(range(n_epochs))
    
    for i in pbar:
        cur_loss = 0
        cur_samples = 0
        
        for input, target in trainloader:
            input = input.to(device)
            target = torch.flatten(target.to(device), start_dim=1)
            
            output = model(input)
    
            optim.zero_grad()
            loss = loss_fn(output, target)
            loss.backward()
            optim.step()
            
            cur_loss += loss.sum().cpu().item()
            cur_samples += input.shape[0]
            pbar.set_postfix(loss=cur_loss / cur_samples)
    
        #cur_loss /= len(trainloader)
        #pbar.set_postfix(prev_loss = cur_loss / cur_samples)

# %% [markdown]
# # The model

# %%
#Classical MLP
def classical_model(param=1000):
    """
    Return a model and its actual number of
    parameters (proportional to `param`)
    """
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(input_dim*history, param),
        nn.ReLU(),
        nn.Linear(param, target_dim)
    )
    return model, sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'Classical MLP size={sum(p.numel() for p in model.parameters() if p.requires_grad)}')
# Out:
# Classical MLP size=201700672

# %%
#Hybrid quantum model impl. with MerLin
def create_block(modes, step, max_param, univ_len):
    cir = pcvl.Circuit(modes)

    for i in range(modes):
        if i+step*modes >= max_param:
            break

        cir.add(i, pcvl.PS(pcvl.P(f'input{i+step*modes}')))

    rl = pcvl.GenericInterferometer(
        modes,
        lambda i: pcvl.BS()
        // pcvl.PS(pcvl.P(f"theta_ri{i+univ_len*step}"))
        // pcvl.BS()
        // pcvl.PS(pcvl.P(f"theta_ro{i+univ_len*step}")),
        shape=pcvl.InterferometerShape.RECTANGLE,
    )
    cir.add(0, rl)

    return cir
    

modes = 10
# left generic interferometer
wl = pcvl.GenericInterferometer(
    modes,
    lambda i: pcvl.BS()
    // pcvl.PS(pcvl.P(f"theta_li{i}"))
    // pcvl.BS()
    // pcvl.PS(pcvl.P(f"theta_lo{i}")),
    shape=pcvl.InterferometerShape.RECTANGLE,
)

circuit = pcvl.Circuit(modes)
circuit.add(0,wl)
for i in range(0, input_dim * history, modes):
    step = i // modes
    circuit.add(0, create_block(modes, step, input_dim * history, len(wl.params)))

quantum_layer = QuantumLayer(
    input_size=input_dim*history,
    circuit=circuit,
    n_photons=3,
    trainable_parameters=["theta"],
    input_parameters=["input"],
    dtype=dataset.X.dtype,
)

def classical_model(param=1000):
    model = nn.Sequential(
        nn.Flatten(),
        quantum_layer,
        LexGrouping(quantum_layer.output_size, 3*param),
        nn.Linear(3*param, target_dim)
    )
    return model, sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'Hybrid quantum model size={sum(p.numel() for p in model.parameters() if p.requires_grad)}')
pcvl.pdisplay(circuit)
# Out:
# Hybrid quantum model size=201700672

# %% [markdown]
# # Playground

# %%
from torch.optim import Adam

device = 'cuda' if torch.cuda.is_available() else 'cpu'
lr = 1e-3
loss_fn = nn.MSELoss()
optim = Adam(model.parameters(), lr=lr)

train(model, loss_fn, optim, device=device, n_epochs=100)
# Out:
#   0%|                                                                                                                                                                                                   | 0/100 [01:43<?, ?it/s, loss=0.00585]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       5 loss_fn = nn.MSELoss()
#       6 optim = Adam(model.parameters(), lr=lr)
# ----> 8 train(model, loss_fn, optim, device=device, n_epochs=100)
#
# Cell In[11], line 20, in train(model, loss_fn, optim, n_epochs, device)
#      18 optim.zero_grad()
#      19 loss = loss_fn(output, target)
# ---> 20 loss.backward()
#      21 optim.step()
#      23 cur_loss += loss.sum().cpu().item()
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
torch.save(model.state_dict(), 'weights/classical_model_hist6.pth')

# %%
example(model, testloader)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 example(model, testloader)
#
# Cell In[10], line 6, in example(model, loader)
#       4 with torch.no_grad():
#       5     inputs, targets = next(iter(loader))
# ----> 6     outputs = model(inputs)
#       8     relative_error = torch.abs(outputs - targets) / (torch.abs(targets) + 1e-7)
#      10     print(f'Target={targets}, Output={outputs}, Rel_error={relative_error}')
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/merlin/algorithms/layer.py:1012, in QuantumLayer.forward(self, shots, sampling_method, simultaneous_processes, *input_parameters)
#    1008             amplitudes = self.computation_process.compute_superposition_state(
#    1009                 params
#    1010             )
#    1011     else:
# -> 1012         amplitudes = self.computation_process.compute(params)
#    1013 finally:
#    1014     if amplitude_input is not None and original_input_state is not None:
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/merlin/core/process.py:163, in ComputationProcess.compute(self, parameters)
#     160 """Compute quantum output distribution."""
#     161 # Generate unitary matrix from parameters
# --> 163 unitary = self.converter.to_tensor(*parameters)
#     164 self.unitary = unitary
#     165 # Compute output distribution using the input state
#
# File ~/Documents/ARTeQ/Hackaton/Hakaton/venv/lib/python3.12/site-packages/merlin/pcvl_pytorch/locirc_to_tensor.py:384, in CircuitConverter.to_tensor(self, batch_size, *input_params)
#     382     # Compose unitaries
#     383     contribution = converted_tensor[..., r[0] : (r[-1] + 1), :].clone()
# --> 384     converted_tensor[..., r[0] : (r[-1] + 1), :] = (
#     385         curr_comp_tensor @ contribution.to(curr_comp_tensor.device)
#     386     )
#     388 if not has_batch:
#     389     # If no batch dimension was provided, remove the batch dimension
#     390     converted_tensor = converted_tensor.squeeze(0)
#
# KeyboardInterrupt:

# %%
test(model, testloader, silent=False)
# Out:
# out shape torch.Size([96, 672])
# Test Results:
# 	 MSE: 0.0632
# 	 Root MSE: 0.2514
# 	 MAE: 0.0632
# 	 R^2 (coefficient of determination): -5.3704
# /tmp/ipykernel_52642/3430668776.py:19: UserWarning: Using a target size (torch.Size([96, 672])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   sum_square = torch.nn.functional.mse_loss(expectancy, targets, reduction='sum').item()  # Basically variance
# (0.06320846080780029,
#  0.2514129288795632,
#  0.06320846080780029,
#  -5.370388748604761)

# %%
#WiP

def predict(df, model):
    complete_df = df[df['Type'] == 'Complete '].copy()
    missing_df = df[df['Type'] == 'Missing Data'].copy()
    incomplete_df = df[df['Type'] == 'Future Prediction'].copy()

    complete_data = completed_df.drop(columns=['Type', 'Date']).values
    t_complete = torch.tensor(completed_data, dtype=torch.float32)

    print(t_completed.shape)
    
    
    #model.test()


samples = pd.read_excel('sample_Simulated_Swaption_Price.xlsx')
predict(samples, None)

samples.head()

# %%
from typing import NamedTuple

class StatResults(NamedTuple):
    mse: float
    root_mse: float
    mae: float
    r_squared: float

results = []
for param in [10, 100, 1000, 5000]:
    model, actual_params = classical_model(param)
    result = StatResults(test(model, testloader))
    results.append(*result)
# Out:
# out shape torch.Size([96, 672])
# /tmp/ipykernel_52642/3430668776.py:19: UserWarning: Using a target size (torch.Size([96, 672])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   sum_square = torch.nn.functional.mse_loss(expectancy, targets, reduction='sum').item()  # Basically variance
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 12
#      10 for param in [10, 100, 1000, 5000]:
#      11     model, actual_params = classical_model(param)
# ---> 12     result = StatResults(test(model, testloader))
#      13     results.append(*result)
#
# TypeError: StatResults.__new__() missing 3 required positional arguments: 'root_mse', 'mae', and 'r_squared'
